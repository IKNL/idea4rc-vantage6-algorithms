# %% [markdown]
# # T-test Algorithm Test using the MockNetwork
# The mock network is intended for testing algorithms without the need of setting up an
# entire vantage6 network.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## MockClient
# We mock to have two organizations with three databases each (<code>rps_cohort</code>, <code>pelvis_cohort</code> and <code>rps_pelvis_cohort</code>). <br><br>
# The first organization has:
# * <code>rps_cohort[:10]</code> (10 pts)
# * <code>pelvis_cohort[:10]</code> (10 pts)
# * <code>rps_pelvis_cohort[:10]</code> (10 pts)
#
# The second organization has:
# * <code>rps_cohort[10:]</code> (304 pts)
# * <code>pelvis_cohort[10:]</code> (276 pts)
# * <code>non_liposarcoma_cohort[10:]</code> (590 pts)

# %%
# Load the dataframes from parquet files
rps_cohort = pd.read_parquet("data/rps_cohort.parquet")
pelvis_cohort = pd.read_parquet("data/pelvis_cohort.parquet")
rps_pelvis_cohort = pd.read_parquet("data/rps_pelvis_cohort.parquet")

# %%
from vantage6.algorithm.mock.network import MockNetwork

network = MockNetwork(
    "v6-analytics",
    datasets=[
        {
            "rps": {"database": rps_cohort[:10], "db_type": "omop"},
            "pelvis": {"database": pelvis_cohort[:10], "db_type": "omop"},
            "rps_pelvis": {"database": rps_pelvis_cohort[:10], "db_type": "omop"}
        },
        {
            "rps": {"database": rps_cohort[10:], "db_type": "omop"},
            "pelvis": {"database": pelvis_cohort[10:], "db_type": "omop"},
            "rps_pelvis": {"database": rps_pelvis_cohort[10:], "db_type": "omop"}
        }
    ],
    collaboration_id=1,
)

client = network.user_client
# Out:
# Error importing in API mode: ImportError("dlopen(/Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so, 0x0002): Library not loaded: /Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib\n  Referenced from: <B96A8100-FA7A-3EFC-8726-931D26646DE6> /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/_rinterface_cffi_api.abi3.so\n  Reason: tried: '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file), '/Library/Frameworks/R.framework/Versions/4.5-arm64/Resources/lib/libRblas.dylib' (no such file)")
# Trying to import in ABI mode.
# info > Using dataframes decorator
# info > Using dataframes decorator
# info > Using dataframes decorator
# info > Using dataframes decorator
# info > Using dataframes decorator
# [info ] - Mock network created with 2 nodes

# %%
# overall summary results
task = client.task.create(
    method="summary",
    organizations=[1],
    arguments={
        "organizations_to_include": [1,2],
    },
    databases=[
        [
            {"type": "dataframe", "dataframe_id": 1},
            {"type": "dataframe", "dataframe_id": 2},
            {"type": "dataframe", "dataframe_id": 3}
        ]
    ],
    action="central_compute"
)
# Out:
# [info ] - Validating function action: central_compute
# info > Creating subtask for all organizations in the collaboration
# [info ] - Validating function action: federated_compute
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# [info ] - Validating function action: federated_compute
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# info > Checking if data complies to privacy settings
# info > Inferred numeric columns: ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/v6-analytics/v6-analytics/summary.py:331: RuntimeWarning: All-NaN slice encountered
#   results["numeric"][var]["median"] = float(np.nanmedian(df[var]))
# /Users/frankmartin/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# info > Waiting for results
# info > Results obtained!
# info > Aggregating partial summaries
# info > n num cols: 7
# info > n means: 7
# info > Aggregating partial summaries
# info > n num cols: 7
# info > n means: 7
# info > Aggregating partial summaries
# info > n num cols: 7
# info > n means: 7
# [info ] - Validating function action: federated_compute
# info > {'columns': ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']}
# info > {'pelvis': [299.93197278911566, 45.91156462585034, 0, 5.3620300751879695, 4004517.0, 1634285.9923076923, 1.0], 'rps_pelvis': [300.5, 47.07833333333333, 0, 5.399630314232903, 4004517.0, 1634301.450367647, 1.0], 'rps': [301.0457516339869, 48.19934640522876, 0, 5.436, 4004517.0, 1634315.602112676, 1.0]}
# info > Cake is a lie
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > {'rps': {'patient_id': 852125.0274680678, 'age': 2838.6980434875477, 'survival_days': 0.0, 'tumor_size': 94.11495999999998, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 1595171.1220118771, 'n_cancer_episodes': 0.0}, 'pelvis': {'patient_id': 830445.9374334768, 'age': 2918.6904530519696, 'survival_days': 0.0, 'tumor_size': 68.2645543840805, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 1430996.6773372537, 'n_cancer_episodes': 0.0}, 'rps_pelvis': {'patient_id': 870332.5, 'age': 2451.1480277777778, 'survival_days': 0.0, 'tumor_size': 105.76726569199914, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 1802664.4621334372, 'n_cancer_episodes': 0.0}}
# [info ] - Validating function action: federated_compute
# info > {'columns': ['patient_id', 'age', 'survival_days', 'tumor_size', 'surgery_concept', 'completeness_of_resection_concept_id', 'n_cancer_episodes']}
# info > {'pelvis': [299.93197278911566, 45.91156462585034, 0, 5.3620300751879695, 4004517.0, 1634285.9923076923, 1.0], 'rps_pelvis': [300.5, 47.07833333333333, 0, 5.399630314232903, 4004517.0, 1634301.450367647, 1.0], 'rps': [301.0457516339869, 48.19934640522876, 0, 5.436, 4004517.0, 1634315.602112676, 1.0]}
# info > Cake is a lie
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > Checking if data complies to privacy settings
# info > Calculating variance
# info > {'rps': {'patient_id': 8491736.332009057, 'age': 83694.14182579349, 'survival_days': 0.0, 'tumor_size': 1715.29864, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 36805108.91672051, 'n_cancer_episodes': 0.0}, 'pelvis': {'patient_id': 7825456.702022305, 'age': 80799.01022722013, 'survival_days': 0.0, 'tumor_size': 1673.861949375318, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 34247617.30727814, 'n_cancer_episodes': 0.0}, 'rps_pelvis': {'patient_id': 17129617.5, 'age': 168584.17030555557, 'survival_days': 0.0, 'tumor_size': 3446.5126603708472, 'surgery_concept': 0.0, 'completeness_of_resection_concept_id': 72395234.19779304, 'n_cancer_episodes': 0.0}}

# %%
results = client.result.from_task(task_id=task.get("id"))
results
# Out:
# [{'pelvis': {'numeric': {'patient_id': {'count': 294.0,
#      'min': 2.0,
#      'max': 600.0,
#      'missing': 0.0,
#      'sum': 88180.0,
#      'median': {'mock-1': 12.0, 'mock-2': 311.0},
#      'q_25': {'mock-1': 8.5, 'mock-2': 170.5},
#      'q_75': {'mock-1': 15.75, 'mock-2': 448.75},
#      'mean': 299.93197278911566,
#      'std': 171.87882309200904},
#     'age': {'count': 294.0,
#      'min': 18.0,
#      'max': 75.0,
#      'missing': 0.0,
#      'sum': 13498.0,
#      'median': {'mock-1': 47.0, 'mock-2': 46.0},
#      'q_25': {'mock-1': 38.75, 'mock-2': 31.0},
#      'q_75': {'mock-1': 68.75, 'mock-2': 60.0},
#      'mean': 45.91156462585034,
#      'std': 16.903429855751188},
#     'survival_days': {'count': 0.0,
#      'min': nan,
#      'max': nan,
#      'missing': 294.0,
#      'sum': 0.0,
#      'median': {'mock-1': nan, 'mock-2': nan},
#      'q_25': {'mock-1': nan, 'mock-2': nan},
#      'q_75': {'mock-1': nan, 'mock-2': nan},
#      'mean': 0,
#      'std': 0.0},
#     'tumor_size': {'count': 266.0,
#      'min': 1.1,
#      'max': 9.9,
#      'missing': 28.0,
#      'sum': 1426.3,
#      'median': {'mock-1': 4.4, 'mock-2': 5.0},
#      'q_25': {'mock-1': 1.8, 'mock-2': 3.2},
#      'q_75': {'mock-1': 7.1, 'mock-2': 7.5},
#      'mean': 5.3620300751879695,
#      'std': 2.5639934240043116},
#     'surgery_concept': {'count': 291.0,
#      'min': 4004517.0,
#      'max': 4004517.0,
#      'missing': 3.0,
#      'sum': 1165314447.0,
#      'median': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_25': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_75': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'mean': 4004517.0,
#      'std': 0.0},
#     'completeness_of_resection_concept_id': {'count': 260.0,
#      'min': 1633801.0,
#      'max': 1634643.0,
#      'missing': 34.0,
#      'sum': 424914358.0,
#      'median': {'mock-1': 1633801.0, 'mock-2': 1634484.0},
#      'q_25': {'mock-1': 1633801.0, 'mock-2': 1633801.0},
#      'q_75': {'mock-1': 1634222.0, 'mock-2': 1634643.0},
#      'mean': 1634285.9923076923,
#      'std': 371.1539658280191},
#     'n_cancer_episodes': {'count': 294.0,
#      'min': 1.0,
#      'max': 1.0,
#      'missing': 0.0,
#      'sum': 294.0,
#      'median': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_25': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_75': {'mock-1': 1.0, 'mock-2': 1.0},
#      'mean': 1.0,
#      'std': 0.0}},
#    'categorical': {'sex': {'count': 294, 'missing': 0},
#     'censor': {'count': 294, 'missing': 0},
#     'status': {'count': 294, 'missing': 0},
#     'histology': {'count': 294, 'missing': 0},
#     'fnclcc_grade': {'count': 294, 'missing': 0},
#     'multifocality': {'count': 294, 'missing': 0},
#     'completeness_of_resection': {'count': 294, 'missing': 0},
#     'tumor_rupture': {'count': 294, 'missing': 0},
#     'pre_operative_chemo': {'count': 294, 'missing': 0},
#     'post_operative_chemo': {'count': 294, 'missing': 0},
#     'pre_operative_radio': {'count': 294, 'missing': 0},
#     'post_operative_radio': {'count': 294, 'missing': 0},
#     'local_recurrence': {'count': 294, 'missing': 0},
#     'distant_metastasis': {'count': 294, 'missing': 0}},
#    'num_complete_rows_per_node': {'mock-1': 0, 'mock-2': 0},
#    'counts_unique_values': {'sex': {'FEMALE': 150, 'MALE': 144},
#     'censor': {'false': 142, 'true': 152},
#     'status': {'ALIVE': 142, 'DEAD': 152},
#     'histology': {'1004/1007 Liposarcoma': 89,
#      '1010 Leiomyosarcoma': 46,
#      '1013 Solitary fibrous tumour': 38,
#      '1016 MPNST': 46,
#      '1019 UPS': 39,
#      '1022 Other sarcomas': 36},
#     'fnclcc_grade': {'Grade 1 tumor': 91,
#      'Grade 3 tumor': 103,
#      'Grade 2 tumor': 97,
#      'N/A': 3},
#     'multifocality': {'MULTIFOCAL TUMOR': 200, 'N/A': 94},
#     'completeness_of_resection': {'Macroscopically complete': 174,
#      'N/A2': 34,
#      'Macroscopically incomplete': 86},
#     'tumor_rupture': {'false': 276, 'true': 18},
#     'pre_operative_chemo': {'false': 234, 'true': 60},
#     'post_operative_chemo': {'false': 209, 'true': 85},
#     'pre_operative_radio': {'true': 92, 'false': 202},
#     'post_operative_radio': {'false': 213, 'true': 81},
#     'local_recurrence': {'false': 294},
#     'distant_metastasis': {'false': 267, 'true': 27}},
#    'organization_id': '1'},
#   'rps_pelvis': {'numeric': {'patient_id': {'count': 600.0,
#      'min': 1.0,
#      'max': 600.0,
#      'missing': 0.0,
#      'sum': 180300.0,
#      'median': {'mock-1': 5.5, 'mock-2': 305.5},
#      'q_25': {'mock-1': 3.25, 'mock-2': 158.25},
#      'q_75': {'mock-1': 7.75, 'mock-2': 452.75},
#      'mean': 300.5,
#      'std': 173.34935823359717},
#     'age': {'count': 600.0,
#      'min': 18.0,
#      'max': 75.0,
#      'missing': 0.0,
#      'sum': 28247.0,
#      'median': {'mock-1': 35.5, 'mock-2': 48.0},
#      'q_25': {'mock-1': 31.25, 'mock-2': 32.0},
#      'q_75': {'mock-1': 47.75, 'mock-2': 62.0},
#      'mean': 47.07833333333333,
#      'std': 16.89777367428822},
#     'survival_days': {'count': 0.0,
#      'min': nan,
#      'max': nan,
#      'missing': 600.0,
#      'sum': 0.0,
#      'median': {'mock-1': nan, 'mock-2': nan},
#      'q_25': {'mock-1': nan, 'mock-2': nan},
#      'q_75': {'mock-1': nan, 'mock-2': nan},
#      'mean': 0,
#      'std': 0.0},
#     'tumor_size': {'count': 541.0,
#      'min': 1.0,
#      'max': 9.9,
#      'missing': 59.0,
#      'sum': 2921.2000000000003,
#      'median': {'mock-1': 5.0, 'mock-2': 5.3},
#      'q_25': {'mock-1': 1.575, 'mock-2': 3.1},
#      'q_75': {'mock-1': 8.15, 'mock-2': 7.5},
#      'mean': 5.399630314232903,
#      'std': 2.5648189330585582},
#     'surgery_concept': {'count': 590.0,
#      'min': 4004517.0,
#      'max': 4004517.0,
#      'missing': 10.0,
#      'sum': 2362665030.0,
#      'median': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_25': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_75': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'mean': 4004517.0,
#      'std': 0.0},
#     'completeness_of_resection_concept_id': {'count': 544.0,
#      'min': 1633801.0,
#      'max': 1634643.0,
#      'missing': 56.0,
#      'sum': 889059989.0,
#      'median': {'mock-1': 1633801.0, 'mock-2': 1634484.0},
#      'q_25': {'mock-1': 1633801.0, 'mock-2': 1633801.0},
#      'q_75': {'mock-1': 1634484.0, 'mock-2': 1634643.0},
#      'mean': 1634301.450367647,
#      'std': 369.6544069657268},
#     'n_cancer_episodes': {'count': 600.0,
#      'min': 1.0,
#      'max': 1.0,
#      'missing': 0.0,
#      'sum': 600.0,
#      'median': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_25': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_75': {'mock-1': 1.0, 'mock-2': 1.0},
#      'mean': 1.0,
#      'std': 0.0}},
#    'categorical': {'sex': {'count': 600, 'missing': 0},
#     'censor': {'count': 600, 'missing': 0},
#     'status': {'count': 600, 'missing': 0},
#     'histology': {'count': 600, 'missing': 0},
#     'fnclcc_grade': {'count': 600, 'missing': 0},
#     'multifocality': {'count': 600, 'missing': 0},
#     'completeness_of_resection': {'count': 600, 'missing': 0},
#     'tumor_rupture': {'count': 600, 'missing': 0},
#     'pre_operative_chemo': {'count': 600, 'missing': 0},
#     'post_operative_chemo': {'count': 600, 'missing': 0},
#     'pre_operative_radio': {'count': 600, 'missing': 0},
#     'post_operative_radio': {'count': 600, 'missing': 0},
#     'local_recurrence': {'count': 600, 'missing': 0},
#     'distant_metastasis': {'count': 600, 'missing': 0}},
#    'num_complete_rows_per_node': {'mock-1': 0, 'mock-2': 0},
#    'counts_unique_values': {'sex': {'FEMALE': 305, 'MALE': 295},
#     'censor': {'false': 300, 'true': 300},
#     'status': {'ALIVE': 300, 'DEAD': 300},
#     'histology': {'1004/1007 Liposarcoma': 163,
#      '1013 Solitary fibrous tumour': 83,
#      '1019 UPS': 84,
#      '1010 Leiomyosarcoma': 87,
#      '1016 MPNST': 94,
#      '1022 Other sarcomas': 89},
#     'fnclcc_grade': {'Grade 1 tumor': 198,
#      'Grade 3 tumor': 187,
#      'Grade 2 tumor': 211,
#      'N/A': 4},
#     'multifocality': {'MULTIFOCAL TUMOR': 420, 'N/A': 180},
#     'completeness_of_resection': {'Macroscopically complete': 371,
#      'Macroscopically incomplete': 173,
#      'N/A2': 56},
#     'tumor_rupture': {'false': 565, 'true': 35},
#     'pre_operative_chemo': {'false': 466, 'true': 134},
#     'post_operative_chemo': {'false': 430, 'true': 170},
#     'pre_operative_radio': {'false': 427, 'true': 173},
#     'post_operative_radio': {'false': 436, 'true': 164},
#     'local_recurrence': {'false': 600},
#     'distant_metastasis': {'false': 544, 'true': 56}},
#    'organization_id': '1'},
#   'rps': {'numeric': {'patient_id': {'count': 306.0,
#      'min': 1.0,
#      'max': 598.0,
#      'missing': 0.0,
#      'sum': 92120.0,
#      'median': {'mock-1': 7.5, 'mock-2': 310.5},
#      'q_25': {'mock-1': 4.25, 'mock-2': 162.5},
#      'q_75': {'mock-1': 13.5, 'mock-2': 470.25},
#      'mean': 301.0457516339869,
#      'std': 175.03031455916172},
#     'age': {'count': 306.0,
#      'min': 18.0,
#      'max': 75.0,
#      'missing': 0.0,
#      'sum': 14749.0,
#      'median': {'mock-1': 34.0, 'mock-2': 50.0},
#      'q_25': {'mock-1': 31.25, 'mock-2': 34.0},
#      'q_75': {'mock-1': 48.0, 'mock-2': 63.25},
#      'mean': 48.19934640522876,
#      'std': 16.843818720219293},
#     'survival_days': {'count': 0.0,
#      'min': nan,
#      'max': nan,
#      'missing': 306.0,
#      'sum': 0.0,
#      'median': {'mock-1': nan, 'mock-2': nan},
#      'q_25': {'mock-1': nan, 'mock-2': nan},
#      'q_75': {'mock-1': nan, 'mock-2': nan},
#      'mean': 0,
#      'std': 0.0},
#     'tumor_size': {'count': 275.0,
#      'min': 1.0,
#      'max': 9.9,
#      'missing': 31.0,
#      'sum': 1494.9,
#      'median': {'mock-1': 5.25, 'mock-2': 5.6},
#      'q_25': {'mock-1': 2.225, 'mock-2': 3.3},
#      'q_75': {'mock-1': 7.775, 'mock-2': 7.5},
#      'mean': 5.436,
#      'std': 2.5697663843378824},
#     'surgery_concept': {'count': 299.0,
#      'min': 4004517.0,
#      'max': 4004517.0,
#      'missing': 7.0,
#      'sum': 1197350583.0,
#      'median': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_25': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'q_75': {'mock-1': 4004517.0, 'mock-2': 4004517.0},
#      'mean': 4004517.0,
#      'std': 0.0},
#     'completeness_of_resection_concept_id': {'count': 284.0,
#      'min': 1633801.0,
#      'max': 1634643.0,
#      'missing': 22.0,
#      'sum': 464145631.0,
#      'median': {'mock-1': 1633801.0, 'mock-2': 1634484.0},
#      'q_25': {'mock-1': 1633801.0, 'mock-2': 1633801.0},
#      'q_75': {'mock-1': 1634484.0, 'mock-2': 1634643.0},
#      'mean': 1634315.602112676,
#      'std': 368.36128389470116},
#     'n_cancer_episodes': {'count': 306.0,
#      'min': 1.0,
#      'max': 1.0,
#      'missing': 0.0,
#      'sum': 306.0,
#      'median': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_25': {'mock-1': 1.0, 'mock-2': 1.0},
#      'q_75': {'mock-1': 1.0, 'mock-2': 1.0},
#      'mean': 1.0,
#      'std': 0.0}},
#    'categorical': {'sex': {'count': 306, 'missing': 0},
#     'censor': {'count': 306, 'missing': 0},
#     'status': {'count': 306, 'missing': 0},
#     'histology': {'count': 306, 'missing': 0},
#     'fnclcc_grade': {'count': 306, 'missing': 0},
#     'multifocality': {'count': 306, 'missing': 0},
#     'completeness_of_resection': {'count': 306, 'missing': 0},
#     'tumor_rupture': {'count': 306, 'missing': 0},
#     'pre_operative_chemo': {'count': 306, 'missing': 0},
#     'post_operative_chemo': {'count': 306, 'missing': 0},
#     'pre_operative_radio': {'count': 306, 'missing': 0},
#     'post_operative_radio': {'count': 306, 'missing': 0},
#     'local_recurrence': {'count': 306, 'missing': 0},
#     'distant_metastasis': {'count': 306, 'missing': 0}},
#    'num_complete_rows_per_node': {'mock-1': 0, 'mock-2': 0},
#    'counts_unique_values': {'sex': {'MALE': 151, 'FEMALE': 155},
#     'censor': {'true': 148, 'false': 158},
#     'status': {'ALIVE': 158, 'DEAD': 148},
#     'histology': {'1019 UPS': 45,
#      '1004/1007 Liposarcoma': 74,
#      '1010 Leiomyosarcoma': 41,
#      '1013 Solitary fibrous tumour': 45,
#      '1016 MPNST': 48,
#      '1022 Other sarcomas': 53},
#     'fnclcc_grade': {'Grade 1 tumor': 107,
#      'Grade 2 tumor': 114,
#      'Grade 3 tumor': 84,
#      'N/A': 1},
#     'multifocality': {'MULTIFOCAL TUMOR': 220, 'N/A': 86},
#     'completeness_of_resection': {'Macroscopically complete': 197,
#      'Macroscopically incomplete': 87,
#      'N/A2': 22},
#     'tumor_rupture': {'false': 289, 'true': 17},
#     'pre_operative_chemo': {'false': 232, 'true': 74},
#     'post_operative_chemo': {'false': 221, 'true': 85},
#     'pre_operative_radio': {'false': 225, 'true': 81},
#     'post_operative_radio': {'false': 223, 'true': 83},
#     'local_recurrence': {'false': 306},
#     'distant_metastasis': {'false': 277, 'true': 29}},
#    'organization_id': '1'}}]
