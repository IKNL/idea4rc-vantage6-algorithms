# %% [markdown]
# # Preprocessing: One hot encoding
# The mock network is intended for testing algorithms without the need of setting up an
# entire vantage6 network.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## MockClient
# We mock to have two organizations with three databases each (<code>rps_cohort</code>, <code>pelvis_cohort</code> and <code>rps_pelvis_cohort</code>). <br><br>
# The first organization has:
# * <code>rps_cohort[:10]</code> (10 pts)
# * <code>pelvis_cohort[:10]</code> (10 pts)
# * <code>rps_pelvis_cohort[:10]</code> (10 pts)
#
# The second organization has:
# * <code>rps_cohort[10:]</code> (304 pts)
# * <code>pelvis_cohort[10:]</code> (276 pts)
# * <code>non_liposarcoma_cohort[10:]</code> (590 pts)

# %%
# Load the dataframes from parquet files
rps_cohort = pd.read_parquet("data/rps_cohort.parquet")
pelvis_cohort = pd.read_parquet("data/pelvis_cohort.parquet")
rps_pelvis_cohort = pd.read_parquet("data/rps_pelvis_cohort.parquet")

# %%
from vantage6.algorithm.mock.network import MockNetwork

network = MockNetwork(
    "v6_preprocessing",
    datasets=[
        {
            "rps": {"database": rps_cohort[:10], "db_type": "omop"},
            "pelvis": {"database": pelvis_cohort[:10], "db_type": "omop"},
            "rps_pelvis": {"database": rps_pelvis_cohort[:10], "db_type": "omop"}
        },
        {
            "rps": {"database": rps_cohort[10:], "db_type": "omop"},
            "pelvis": {"database": pelvis_cohort[10:], "db_type": "omop"},
            "rps_pelvis": {"database": rps_pelvis_cohort[10:], "db_type": "omop"}
        }
    ],
    collaboration_id=1,
)

client = network.user_client
# Out:
# [info ] - Mock network created with 2 nodes

# %%
client.dataframe.preprocess(
    id_=1,
    method="one_hot_encode",
    image="v6-preprocessing",
    arguments={
        "column": "histology",
        "categories": [
                "1004/1007 Liposarcoma",
                "1013 Solitary fibrous tumour",
                "1016 MPNST",
                "1019 UPS",
                "1022 Other sarcomas"
            ],
        "unknown_category": "unknown",
        "prefix": "histology",
        "drop_original": False
    }
)
# Out:
# [info ] - Validating function action: preprocessing
# error > Error simulating dataframe preprocessing for organization 1: 'histology'
# error > Exiting...
# Traceback (most recent call last):
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     return self._engine.get_loc(casted_key)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "pandas/_libs/index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7096, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'histology'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/client.py", line 630, in preprocess
#     df = node.simulate_dataframe_preprocessing(
#         data_frame_name, image, method, arguments
#     )
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/node.py", line 234, in simulate_dataframe_preprocessing
#     result = self.run(
#         method_fn, {**arguments, **mocked_kwargs}, task_env_vars=task_env_vars
#     )
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/node.py", line 262, in run
#     return method_fn(**arguments)
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/decorator/data.py", line 232, in decorator
#     return func(*mock_data, *args, **kwargs)
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/decorator/action.py", line 216, in wrapper
#     result = func(*args, **kwargs)
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/v6-preprocessing/src/v6_preprocessing/one_hot_encode.py", line 76, in one_hot_encode
#     df_copy[column] = df_copy[column].apply(
#                       ~~~~~~~^^^^^^^^
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/frame.py", line 4113, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/Users/frank/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py", line 3819, in get_loc
#     raise KeyError(key) from err
# KeyError: 'histology'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'histology'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/client.py:630, in MockUserClient.Dataframe.preprocess(self, id_, image, method, arguments)
#     629 try:
# --> 630     df = node.simulate_dataframe_preprocessing(
#     631         data_frame_name, image, method, arguments
#     632     )
#     633 except SessionActionMismatchError:
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/node.py:234, in MockNode.simulate_dataframe_preprocessing(self, dataframe_name, image, method, arguments)
#     232     mocked_kwargs["mock_data"] = [mock_data]
# --> 234 result = self.run(
#     235     method_fn, {**arguments, **mocked_kwargs}, task_env_vars=task_env_vars
#     236 )
#     237 df = result.to_pandas()
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/node.py:262, in MockNode.run(self, method_fn, arguments, task_env_vars)
#     261 with env_vars(**task_env_vars):
# --> 262     return method_fn(**arguments)
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/decorator/data.py:232, in dataframe.<locals>.protection_decorator.<locals>.decorator(mock_data, *args, **kwargs)
#     231 if mock_data is not None:
# --> 232     return func(*mock_data, *args, **kwargs)
#     234 # get the dataframe names that the user requested
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/decorator/action.py:216, in preprocessing.<locals>.wrapper(*args, **kwargs)
#     214 _exit_if_action_mismatch(AlgorithmStepType.PREPROCESSING)
# --> 216 result = func(*args, **kwargs)
#     218 return _convert_to_parquet(result)
#
# File ~/Repositories/idea4rc-vantage6-algorithms/v6-preprocessing/src/v6_preprocessing/one_hot_encode.py:76, in one_hot_encode(df, column, categories, unknown_category, drop_original, prefix)
#      75 df_copy = df.copy()
# ---> 76 df_copy[column] = df_copy[column].apply(
#      77     lambda x: x if x in categories else unknown_category
#      78 )
#      80 # Perform one-hot encoding
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#
# KeyError: 'histology'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 client.dataframe.preprocess(
#       2     id_=1,
#       3     method="one_hot_encode",
#       4     image="v6-preprocessing",
#       5     arguments={
#       6         "column": "histology",
#       7         "categories": [
#       8                 "1004/1007 Liposarcoma",
#       9                 "1013 Solitary fibrous tumour",
#      10                 "1016 MPNST",
#      11                 "1019 UPS",
#      12                 "1022 Other sarcomas"
#      13             ],
#      14         "unknown_category": "unknown",
#      15         "prefix": "histology"
#      16     }
#      17 )
#
# File ~/Repositories/idea4rc-vantage6-algorithms/.venv/lib/python3.13/site-packages/vantage6/algorithm/mock/client.py:644, in MockUserClient.Dataframe.preprocess(self, id_, image, method, arguments)
#     642     error("Exiting...")
#     643     traceback.print_exc()
# --> 644     exit(1)
#     645 dataframes.append(df)
#     647 result_response = self.parent.network.server.save_result({}, task["id"])
#
# NameError: name 'exit' is not defined

# %%
client.network.get_node(1).dataframes["rps"]
# Out:
#    patient_id   age     sex  censor status  survival_days   fnclcc_grade  \
# 0         1.0  31.0  FEMALE    True   DEAD            NaN  Grade 3 tumor
# 1         3.0  68.0  FEMALE   False  ALIVE            NaN  Grade 2 tumor
# 2         4.0  34.0  FEMALE    True   DEAD            NaN  Grade 2 tumor
# 3         5.0  22.0    MALE   False  ALIVE            NaN  Grade 1 tumor
# 4         6.0  32.0  FEMALE   False  ALIVE            NaN  Grade 1 tumor
# 5         9.0  49.0    MALE   False  ALIVE            NaN  Grade 3 tumor
# 6        12.0  45.0    MALE    True   DEAD            NaN  Grade 2 tumor
# 7        14.0  34.0    MALE    True   DEAD            NaN  Grade 1 tumor
# 8        18.0  25.0    MALE    True   DEAD            NaN  Grade 3 tumor
# 9        20.0  64.0    MALE   False  ALIVE            NaN  Grade 1 tumor
#
#    tumor_size              surgery_date  surgery_concept  ...  \
# 0         5.6 2020-07-03 00:00:00+00:00        4004517.0  ...
# 1         8.5 2021-12-20 00:00:00+00:00        4004517.0  ...
# 2         1.3 2019-03-12 00:00:00+00:00        4004517.0  ...
# 3         9.2 2024-02-26 00:00:00+00:00        4004517.0  ...
# 4         9.5 2024-12-11 00:00:00+00:00        4004517.0  ...
# 5         1.4 2022-08-09 00:00:00+00:00        4004517.0  ...
# 6         5.6 2019-10-14 00:00:00+00:00        4004517.0  ...
# 7         2.3 2024-01-10 00:00:00+00:00        4004517.0  ...
# 8         4.9 2022-11-03 00:00:00+00:00        4004517.0  ...
# 9         2.2 2022-05-19 00:00:00+00:00        4004517.0  ...
#
#   post_operative_radio local_recurrence  distant_metastasis  \
# 0                 True            False               False
# 1                 True            False               False
# 2                 True            False               False
# 3                False            False               False
# 4                False            False               False
# 5                False            False               False
# 6                False            False               False
# 7                 True            False               False
# 8                False            False               False
# 9                False            False               False
#
#    n_cancer_episodes  histology_1004/1007 Liposarcoma  histology_unknown  \
# 0                1.0                            False              False
# 1                1.0                            False              False
# 2                1.0                             True              False
# 3                1.0                            False              False
# 4                1.0                             True              False
# 5                1.0                             True              False
# 6                1.0                            False              False
# 7                1.0                            False               True
# 8                1.0                            False              False
# 9                1.0                            False              False
#
#    histology_1013 Solitary fibrous tumour  histology_1016 MPNST  \
# 0                                    True                 False
# 1                                   False                 False
# 2                                   False                 False
# 3                                   False                 False
# 4                                   False                 False
# 5                                   False                 False
# 6                                   False                 False
# 7                                   False                 False
# 8                                   False                  True
# 9                                   False                 False
#
#    histology_1019 UPS  histology_1022 Other sarcomas
# 0               False                          False
# 1                True                          False
# 2               False                          False
# 3                True                          False
# 4               False                          False
# 5               False                          False
# 6                True                          False
# 7               False                          False
# 8               False                          False
# 9                True                          False
#
# [10 rows x 27 columns]
