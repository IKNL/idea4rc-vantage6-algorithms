# %% [markdown]
# # Sarcoma Use Case
#
# ### Algorithms
# * Summary
# * Crosstab
# * Chi Square
# * t-test
# * GLM
#
# ### Basic data items
# * [x] Sex (Male/Female)
# * [x] FNCLCC grade (frequencies)
# * [x] Patient status (Dead/Alive)
# * [x] Tumor size (mean, median per center, IQR)
#   * Dimension of Tumor - 36768664 -- MEASUREMENT.measurement_concept_id
# * [x] Age (mean, median per center, IQR)
# * [x] Multifocality (Unifocal/Multifocal)
# * [x] Completeness of resection (R0/R1, R2)
# * [x] Tumor rupture (Yes/No)
# * [x] Chemotherapy (Yes/No)
# * [x] Radiotherapy (Yes/No)
# * [x] Local recurrence (Yes/No)
# * [x] Distant metastases (Yes/No)
# * [x] Count of RPS episodes for every patient

# %%
import psycopg2
import pandas as pd

# %%
## Database related
def establish_connection():
    dbname = "omopdb"
    user = "ohdsi"
    password = "ohdsi"
    host = "localhost"
    port = "5432"

    conn = psycopg2.connect(
        dbname=dbname,
        user=user,
        password=password,
        host=host,
        port=port
    )

    cur = conn.cursor()
    return conn, cur

# %%
with open('./query.sql', 'r') as file: query = file.read()
conn, cur = establish_connection()
cur.execute(query)
data = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
df = pd.DataFrame(data, columns=column_names)
print(df)
# Out:
#      patient_id age     sex censor status  survival_days   fnclcc_grade  \
# 0             1  55  FEMALE      1   DEAD           2682  Grade 2 tumor
# 1             2  41    MALE      0  ALIVE           1639            N/A
# 2             3  35    MALE      1   DEAD            269  Grade 2 tumor
# 3             4  73    MALE      0  ALIVE            408  Grade 2 tumor
# 4             5  52    MALE      1   DEAD            115  Grade 3 tumor
# ..          ...  ..     ...    ...    ...            ...            ...
# 755         756  51  FEMALE      1   DEAD            426  Grade 3 tumor
# 756         757  12  FEMALE      0  ALIVE           2294  Grade 1 tumor
# 757         758  53    MALE      0  ALIVE           1168  Grade 3 tumor
# 758         759  43  FEMALE      1   DEAD            901  Grade 3 tumor
# 759         760  30  FEMALE      1   DEAD            625  Grade 3 tumor
#
#     tumor_size multifocality completeness_of_resection  tumor_rupture  \
# 0         None           N/A                       N/A              0
# 1         None           N/A                       N/A              0
# 2         None           N/A                       N/A              0
# 3         None           N/A                       N/A              0
# 4         None           N/A                       N/A              0
# ..         ...           ...                       ...            ...
# 755       None           N/A                       N/A              0
# 756       None           N/A                       N/A              0
# 757       None           N/A                       N/A              0
# 758       None           N/A                       N/A              0
# 759       None           N/A                       N/A              0
#
#      pre_operative_chemo  post_operative_chemo  pre_operative_radio  \
# 0                      0                     0                    0
# 1                      0                     0                    0
# 2                      0                     0                    0
# 3                      0                     0                    0
# 4                      0                     0                    0
# ..                   ...                   ...                  ...
# 755                    0                     0                    0
# 756                    0                     0                    0
# 757                    0                     0                    0
# 758                    0                     0                    0
# 759                    0                     0                    0
#
#      post_operative_radio  local_recurrence  distant_metastasis  \
# 0                       0                 0                   0
# 1                       0                 0                   0
# 2                       0                 0                   0
# 3                       0                 0                   0
# 4                       0                 0                   0
# ..                    ...               ...                 ...
# 755                     0                 0                   0
# 756                     0                 0                   0
# 757                     0                 0                   0
# 758                     0                 0                   0
# 759                     0                 0                   0
#
#      n_cancer_episodes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 755                  0
# 756                  0
# 757                  0
# 758                  0
# 759                  0
#
# [760 rows x 18 columns]
